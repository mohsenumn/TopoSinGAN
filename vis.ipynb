# %%
from skimage.io import imshow, imread, imsave
import numpy as np
import os
import matplotlib.pyplot as plt
path = "params/TrainedModels/TrainedModels_1221/dendro_skel/scale_factor=0.75,alpha=10/8/fake_sample.png"
im = imread(path)
imshow(im[:,:,-1])

# %%
from skimage import io, transform
from skimage.io import imshow, imread, imsave
import matplotlib.pyplot as plt

image = io.imread('Input/Images/dendro_skel.png')  # Replace with your image path

# Double the dimensions of the image
enlarged_image = transform.resize(image, (image.shape[0] * 2, image.shape[1] * 2))
enlarged_image3= transform.resize(image, (image.shape[0] * 3, image.shape[1] * 3))

imsave('Input/Images/dendro_skel_double.png', enlarged_image.astype('uint8'))
imsave('Input/Images/dendro_skel_triple.png', enlarged_image3.astype('uint8'))
# Out:
# /tmp/ipykernel_495912/925468491.py:11: UserWarning: Input/Images/dendro_skel_double.png is a low contrast image
#   imsave('Input/Images/dendro_skel_double.png', enlarged_image.astype('uint8'))
# /tmp/ipykernel_495912/925468491.py:12: UserWarning: Input/Images/dendro_skel_triple.png is a low contrast image
#   imsave('Input/Images/dendro_skel_triple.png', enlarged_image3.astype('uint8'))

# %%
image.shape
# Out:
# (175, 240, 4)

# %%
import shutil
shutil.copy(source_path, dir2save)

# %%
import os
os.path.join('a/', 'b/')
# Out:
# 'a/b/'

# %%
path = "params/TrainedModels/TrainedModels_1221/dendro_skel/scale_factor=0.75,alpha=10/6/fake_sample.png"
#imshow(path)
im = imread(path)


imshow(im[:,:,-1])

# %%
# !sbatch job.sh
# Out:
# Submitted batch job 76545
